# %% [markdown]
# <a href="https://colab.research.google.com/github/HyungJunByun/practice-history/blob/main/%ED%86%B5%EA%B3%84%ED%95%99_%EC%8B%A4%ED%97%98_5%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from scipy.stats import binom

import numpy as np
import matplotlib.pyplot as plt

x=np.arange(0,7)

px=binom.pmf(x, n=6, p=0.5)

plt.plot(x,px)

plt.vlines(x,0,px, linewidth=2.0)

plt.title("Binomial distribution")

plt.show()

# %%
print(binom.cdf(k=5,n=20,p=0.1))
# Out:
# 0.988746865835491

# %%
import numpy as np
from scipy.stats import binom
from scipy.stats import norm
import matplotlib.pyplot as plt

p=0.2; n=20

k=np.arange(0,n+1)
px=binom.pmf(k,n=n,p=p)
plt.plot(k,px,'C1o')
plt.plot(k,px,color='C1',linewidth=2.0)

x=np.linspace(-5,15,100, endpoint=True)

mu=n*p
sd=np.sqrt(n*p*(1-p))
fx=norm.pdf(x,loc=mu,scale=sd)
plt.plot(x,fx,linewidth=1.0,linestyle='-')

plt.title('normal approximation, p=0.2, n=%i'%n)
plt.ylabel('probability')

plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import uniform
from scipy.stats import norm

np.random.seed(0)

n=10
mean=[]

for i in range(1000):
  x=uniform.rvs(loc=0,scale=1,size=n)
  mean.append(x.mean())

plt.hist(mean, bins=9, density=True, histtype='bar')

x=np.linspace(0,1,100,endpoint=True)
mu=0.5
sd=np.sqrt(1/12)
fx=norm.pdf(x, loc=mu, scale=sd/np.sqrt(n))
plt.plot(x,fx,color='C3', linewidth=3.0, linestyle='-')

plt.title("distribution of the Sample Mean n = %i" %n)
plt.xlabel('mean')
plt.ylabel('density')
plt.show()
